# %% [markdown]
# 1 Passo - Importar a base de dados
#
# 2 Passo - Verificar a base de dados e excluir e cancelar o que não vai me beneficiar na análise
#
# 3 Passo - Dar uma visualisada na base de dados. Fazer uma análise do que eu preciso. Exemplo: Gerar percentual de clientes e cancelados para uma análise profunda do que está acontecendo.
#
# 4 Passo - Análise Profunda dos dados. Gerando insights valiosos, e ajudar a empresa descobrir o motivo do problema
#
# Objetivo:
# Prever se um usuário irá sair ou permanecer ativo. Ajudar o spotify a reduzir os cancelamentos. Gerando insights valiosos e prevendo e dizendo a empresa o que está acontecendo pro cliente cancelar
#
# Caso de Uso:
# Analisar padrões de Engajamento e ajudar o spotify a reduzir os cancelamentos

# %%
# 1 Passo - Importar a base de dados
import pandas as pd
tabela = pd.read_csv("spotify_churn_dataset.csv")

# 2 Passo - Verificar a base de dados e excluir e cancelar o que não vai me beneficiar na análise
tabela = tabela.drop("user_id", axis=1)
display(tabela)
# Out:
#       gender  age country subscription_type  listening_time  \
# 0     Female   54      CA              Free              26
# 1      Other   33      DE            Family             141
# 2       Male   38      AU           Premium             199
# 3     Female   22      CA           Student              36
# 4      Other   29      US            Family             250
# ...      ...  ...     ...               ...             ...
# 7995   Other   44      DE           Student             237
# 7996    Male   34      AU           Premium              61
# 7997  Female   17      US              Free              81
# 7998  Female   34      IN           Student             245
# 7999   Other   45      AU              Free             210
#
#       songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                       23       0.20     Desktop                     31
# 1                       62       0.34         Web                      0
# ...

# %% [markdown]
# A seguir, visualizei a base de dados para obter informações que auxiliassem na análise. Para isso, verifiquei se a tabela continha valores vazios ou pendentes e realizei capturas de tela (prints) para confirmar se todas as tabelas estavam presentes na base de dados.

# %%
# 3 Passo - Dar uma visualisada na base de dados. Fazer uma análise do que eu preciso



display(tabela.info())
print(tabela.columns)
display(tabela.describe())



membro_por_tipo_plano = tabela[["subscription_type", "ads_listened_per_week"]].groupby("subscription_type").value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 8000 non-null   object
#  1   age                    8000 non-null   int64
#  2   country                8000 non-null   object
#  3   subscription_type      8000 non-null   object
#  4   listening_time         8000 non-null   int64
#  5   songs_played_per_day   8000 non-null   int64
#  6   skip_rate              8000 non-null   float64
#  7   device_type            8000 non-null   object
#  8   ads_listened_per_week  8000 non-null   int64
#  9   offline_listening      8000 non-null   int64
#  10  is_churned             8000 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 687.6+ KB
# None
# Index(['gender', 'age', 'country', 'subscription_type', 'listening_time',
# ...

# %% [markdown]
# Em seguida, foi feita uma verificação na base de dados, e observou-se que há uma quantidade pequena de clientes que utilizam o plano Free. (Ponto importante)

# %%
# 3 Passo - Dar uma visualisada na base de dados. Fazer uma análise do que eu preciso

membro_por_tipo_plano = tabela[["subscription_type", "ads_listened_per_week", "is_churned"]].groupby("subscription_type").value_counts()
display(membro_por_tipo_plano)
# Out:
# subscription_type  ads_listened_per_week  is_churned
# Family             0                      0             1383
#                                           1              525
# Free               44                     0               45
#                    47                     0               42
#                    13                     0               40
#                                                         ...
#                    10                     1                3
# Premium            0                      0             1585
#                                           1              530
# Student            0                      0             1446
#                                           1              513
# Name: count, Length: 96, dtype: int64

# %% [markdown]
# Graficos abaixo foram elaboradas para verificar se os tipos de assinatura (Free, Premium, Student, Family),  influenciam um possível cancelamento de assinatura ou em um eventual abandono do uso do Spotify.

# %%
# 4 Passo - Análise final para gerar insights valiosos
for coluna in tabela:
    grafico = px.histogram(tabela, x=coluna, color="subscription_type", width = 500, height = 500)
    grafico.show()

# %%
#Criando barras

#dados_x = [1990, 2000, 2010, 2020]
#dados_y = [10, 20, 30, 40]
#fig = px.bar(x = dados_x, y = dados_y)

#fig.show()

# %% [markdown]
# Avaliação Inicial:
#
# 1º - Todas as colunas e linhas tem todos os seus valores preenchidos. Sendo assim, não há valor vazio.
#
# 2º - O problema não é no tipo de inscrição, pois todos os tipos de planos tem uma quantidade exata de membros. Portanto é necessário verificar outras colunas.

# %% [markdown]
# Análise Final:
#
# 1º - Quanto mais anúncios houver no plano Free, mais clientes a empresa poderá perder ou ganhar. Por isso, é importante oferecer um plano acessível, com um bom preço, para aqueles clientes que estão no plano Free.
#
# 2º - A questão é que não há muito cancelamento na base de dados. Porém, o problema existente é o excesso de anúncios para os clientes do plano Free. Portanto, é ideal que os responsáveis pelo Spotify ofereçam um plano mais acessível para esses usuários, pois a probabilidade de eles pararem de usar o aplicativo é grande.
#
# 3º - Como o plano Free não possui opção de cancelamento, não há registros significativos nessa categoria. No entanto, uma estratégia positiva para o Spotify seria oferecer um período de teste grátis, proporcionando ao usuário uma experiência sem anúncios. Essa iniciativa aumenta o conforto na utilização do aplicativo e eleva a probabilidade de conversão em cliente pagante.
#
# Sugestão Ideal Para empresa - Sugere-se ofecerer um teste grátis acessível para esses clientes. Um período de 1 mês seria suficiente para conquistar novos usuários para empresa, e há a possibildade de que o cliente não cancele. Por isso, esse método é essencial!
